# %%
import sys
import pandas as pd
df = pd.read_csv('../data/youtuber/yukirinu.csv', index_col=0)
df['like_dislike'] = df['likeCount'] / df['dislikeCount']
sprite_size = 32 if len(df.index)>50000 else 64
jsonstr = df.to_json(orient='records')

# %%
# Display the Dive visualization for this data
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))

# Create Facets template  
HTML_TEMPLATE = """<link rel="import" href="/nbextensions/facets-dist/facets-jupyter.html">
        <facets-dive sprite-image-width="{sprite_size}" sprite-image-height="{sprite_size}" id="elem" height="600"></facets-dive>
        <script>
          document.querySelector("#elem").data = {jsonstr};
        </script>"""

# Load the json dataset and the sprite_size into the template
html = HTML_TEMPLATE.format(jsonstr=jsonstr,
                            sprite_size=sprite_size,
                            atlas_url="complete_image.jpg")

# Display the template
display(HTML(html))
# Out:
# <style>.container { width:90% !important; }</style>
# <link rel="import" href="/nbextensions/facets-dist/facets-jupyter.html">
#         <facets-dive sprite-image-width="64" sprite-image-height="64" id="elem" height="600"></facets-dive>
#         <script>
#           document.querySelector("#elem").data = [{"id":"IoPEHz9HcK4","title":"\u597d\u304d\u306a\u4eba\u304c\u3067\u304d\u3066\u3057\u307e\u3044\u307e\u3057\u305f\u3002\u3002\u3086\u304d\u308a\u306c\u5148\u751f\u306e\u8cea\u554f\u76f8\u8ac7\u30b3\u30fc\u30ca\u30fc","description":"\u5c11\u3057\u3067\u3082\u826f\u3044\u3068\u601d\u3063\u3066\u3082\u3089\u3048\u305f\u3089\u9ad8\u8a55\u4fa1\u304a\u306d\u304c\u3044\u3057\u307e\u3059\u0669(\u0e51\u275b\u1d17\u275b\u0e51)\u06f6 \r\n\r\n\r\n\r\n\u3086\u304d\u308a\u306c 1st \u30d5\u30a9\u30c8\u30d6\u30c3\u30af\u304c7\/6(\u91d1)\u306b\u767a\u58f2\u3055\u308c\u307e\u3059\uff01\r\nAmazon\u3067\u4e88\u7d04\u53d7\u4ed8\u4e2d\u3067\u3059\uff01\r\n\u2192\u3000https:\/\/amzn.to\/2KeU9m1\r\n\r\n\u3055\u3089\u306b7\/8(\u65e5)\u306b\u30d5\u30a9\u30c8\u30d6\u30c3\u30af\u767a\u58f2\u3092\u8a18\u5ff5\u3057\u305f\u30a4\u30d9\u30f3\u30c8\u304c\u3042\u308a\u307e\u3059\uff01\r\n\u7dca\u5f35\u3059\u308b\u3051\u3069\u307f\u3093\u306a\u4f1a\u3044\u306b\u6765\u3066\u306d\uff01\r\n\u2192\u3000http:\/\/www.hmv.co.jp\/store\/event\/33603\/\r\n\r\n\u3010\u3086\u304d\u308a\u306c\u3011\r\n\u30e1\u30a4\u30f3\r\n\u2192\u3000http:\/\/goo.gl\/jv5JIc\r\n\r\n\u30b5\u30d6\u30c1\u30e3\u30f3\u30cd\u30eb(\u30e1\u30a4\u30f3\u3088\u308a\u3082\u3063\u3068\u3086\u308b\u3044\u52d5\u753b)\r\n\u21e8\u3000http:\/\/goo.gl\/TMzYZM\r\n\r\nTwitter\r\n\u21e8\u3000https:\/\/twitter.com\/yukirin_u\r\n\r\nInstagram\r\n\u21e8\u3000https:\/\/www.instagram.com\/yukirin_u\/\r\n\r\n\r\n\u3010\u4f7f\u7528\u697d\u66f2\u306